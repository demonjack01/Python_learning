# %%
import cv2  #! 读取的格式是BGR
import matplotlib.pyplot as plt
img=cv2.imread('touxiang.jpg')
img
# Out:
# array([[[196, 196, 196],
#         [204, 204, 204],
#         [191, 190, 194],
#         ...,
#         [151, 145, 164],
#         [148, 142, 161],
#         [145, 139, 158]],
#
#        [[192, 192, 192],
#         [201, 201, 201],
#         [196, 195, 197],
#         ...,
#         [150, 144, 163],
#         [148, 142, 161],
#         [146, 140, 159]],
#
#        [[191, 192, 190],
#         [197, 197, 197],
#         [202, 201, 203],
#         ...,
#         [149, 143, 162],
#         [148, 142, 161],
#         [147, 141, 160]],
#
#        ...,
#
#        [[208, 208, 224],
#         [207, 207, 223],
#         [206, 206, 222],
#         ...,
#         [210, 192, 199],
#         [210, 192, 199],
#         [210, 192, 199]],
#
#        [[209, 209, 227],
#         [206, 206, 224],
#         [205, 205, 223],
#         ...,
#         [210, 192, 199],
#         [210, 192, 199],
#         [210, 192, 199]],
#
#        [[209, 208, 228],
#         [205, 204, 224],
#         [204, 203, 223],
# ...

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (639, 640, 3)

# %%
img2=cv2.imread('touxiang.jpg',cv2.IMREAD_GRAYSCALE)
img2
# Out:
# array([[196, 204, 191, ..., 151, 148, 145],
#        [192, 201, 196, ..., 150, 148, 146],
#        [191, 197, 202, ..., 149, 148, 147],
#        ...,
#        [213, 212, 211, ..., 196, 196, 196],
#        [214, 211, 210, ..., 196, 196, 196],
#        [214, 210, 209, ..., 196, 196, 196]], dtype=uint8)

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('huise.jpg',img2)
# Out:
# True

# %%
touxiang=img[0:200,0:200]
cv2.imshow('image',touxiang)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
b,g,r=cv2.split(img)
b
# Out:
# array([[196, 204, 191, ..., 151, 148, 145],
#        [192, 201, 196, ..., 150, 148, 146],
#        [191, 197, 202, ..., 149, 148, 147],
#        ...,
#        [208, 207, 206, ..., 210, 210, 210],
#        [209, 206, 205, ..., 210, 210, 210],
#        [209, 205, 204, ..., 210, 210, 210]], dtype=uint8)

# %%
img_r=img.copy()
img_r[:,:,0]=0     
img_r[:,:,1]=0 
img_r
# Out:
# array([[[  0,   0, 196],
#         [  0,   0, 204],
#         [  0,   0, 194],
#         ...,
#         [  0,   0, 164],
#         [  0,   0, 161],
#         [  0,   0, 158]],
#
#        [[  0,   0, 192],
#         [  0,   0, 201],
#         [  0,   0, 197],
#         ...,
#         [  0,   0, 163],
#         [  0,   0, 161],
#         [  0,   0, 159]],
#
#        [[  0,   0, 190],
#         [  0,   0, 197],
#         [  0,   0, 203],
#         ...,
#         [  0,   0, 162],
#         [  0,   0, 161],
#         [  0,   0, 160]],
#
#        ...,
#
#        [[  0,   0, 224],
#         [  0,   0, 223],
#         [  0,   0, 222],
#         ...,
#         [  0,   0, 199],
#         [  0,   0, 199],
#         [  0,   0, 199]],
#
#        [[  0,   0, 227],
#         [  0,   0, 224],
#         [  0,   0, 223],
#         ...,
#         [  0,   0, 199],
#         [  0,   0, 199],
#         [  0,   0, 199]],
#
#        [[  0,   0, 228],
#         [  0,   0, 224],
#         [  0,   0, 223],
# ...

# %%
cv2.imshow('image',img_r)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
top_size,bottom_size,left_size,right_size=(50,50,50,50)

# %%
res=cv2.addWeighted(img,0.8,img_r,0.2,0)
plt.imshow(res)
